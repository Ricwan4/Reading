# %%
import numpy as np
import pandas as pd

df = pd.read_excel('Attention_Behavior.xlsx', sheet_name='Sheet1')

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import statsmodels.api as sm
from matplotlib.ticker import MaxNLocator

x = df['G_AB_Sclae']
y = df['G_Acc']

x_with_const = sm.add_constant(x)
model = sm.OLS(y, x_with_const).fit()

x_pred = np.linspace(x.min(), x.max(), 100)
x_pred_with_const = sm.add_constant(x_pred)

predictions = model.get_prediction(x_pred_with_const)
pred_summary = predictions.summary_frame(alpha=0.05)  # 95% CI

mean_pred = pred_summary['mean'].values
mean_ci_lower = pred_summary['mean_ci_lower'].values
mean_ci_upper = pred_summary['mean_ci_upper'].values

# plot
fig, ax = plt.subplots(figsize=(10, 8))

ax.scatter(x, y, color='#fbb4ae', s=50)
ax.plot(x_pred, mean_pred, color='#e41a1c', linewidth=2) 
ax.fill_between(x_pred, mean_ci_lower, mean_ci_upper, color='#e41a1c', alpha=0.3)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(1)
ax.xaxis.set_major_locator(MaxNLocator(nbins=7))

# Lables
corr, p_value = stats.pearsonr(x, y)
ax.set_title(f"Pearson r = {corr:.2f}, p = {p_value:.3f}", fontsize=24)
ax.set_xlabel('G-L Scale', fontsize=24)
ax.set_ylabel('Accuracy', fontsize=24)

ax.tick_params(axis='both', which='major', labelsize=20)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import statsmodels.api as sm
from matplotlib.ticker import MaxNLocator

x = df['G_AB_Sclae']
y = df['G_RT']

x_with_const = sm.add_constant(x)
model = sm.OLS(y, x_with_const).fit()

x_pred = np.linspace(x.min(), x.max(), 100)
x_pred_with_const = sm.add_constant(x_pred)

predictions = model.get_prediction(x_pred_with_const)
pred_summary = predictions.summary_frame(alpha=0.05)  # 95% CI

mean_pred = pred_summary['mean'].values
mean_ci_lower = pred_summary['mean_ci_lower'].values
mean_ci_upper = pred_summary['mean_ci_upper'].values

# plot
fig, ax = plt.subplots(figsize=(10, 8))

ax.scatter(x, y, color='#fbb4ae', s=50)
ax.plot(x_pred, mean_pred, color='#e41a1c', linewidth=2) 
ax.fill_between(x_pred, mean_ci_lower, mean_ci_upper, color='#e41a1c', alpha=0.3)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(1)
ax.xaxis.set_major_locator(MaxNLocator(nbins=7))

# Lables
corr, p_value = stats.pearsonr(x, y)
ax.set_title(f"Pearson r = {corr:.2f}, p = {p_value:.3f}", fontsize=24)
ax.set_xlabel('G-L Scale', fontsize=24)
ax.set_ylabel('Reading Time', fontsize=24)

ax.tick_params(axis='both', which='major', labelsize=20)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import statsmodels.api as sm
from matplotlib.ticker import MaxNLocator

x = df['L_AB_Sclae']
y = df['L_Acc']

x_with_const = sm.add_constant(x)
model = sm.OLS(y, x_with_const).fit()

x_pred = np.linspace(x.min(), x.max(), 100)
x_pred_with_const = sm.add_constant(x_pred)

predictions = model.get_prediction(x_pred_with_const)
pred_summary = predictions.summary_frame(alpha=0.05)  # 95% CI

mean_pred = pred_summary['mean'].values
mean_ci_lower = pred_summary['mean_ci_lower'].values
mean_ci_upper = pred_summary['mean_ci_upper'].values

# plot
fig, ax = plt.subplots(figsize=(10, 8))

ax.scatter(x, y, color='#b3cde3', s=50)
ax.plot(x_pred, mean_pred, color='#377eb8', linewidth=2) 
ax.fill_between(x_pred, mean_ci_lower, mean_ci_upper, color='#377eb8', alpha=0.3)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(1)
ax.xaxis.set_major_locator(MaxNLocator(nbins=7))

# Lables
corr, p_value = stats.pearsonr(x, y)
ax.set_title(f"Pearson r = {corr:.2f}, p = {p_value:.3f}", fontsize=24)
ax.set_xlabel('G-L Scale', fontsize=24)
ax.set_ylabel('Accuracy', fontsize=24)

ax.tick_params(axis='both', which='major', labelsize=20)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import statsmodels.api as sm
from matplotlib.ticker import MaxNLocator

x = df['L_AB_Sclae']
y = df['L_RT']

x_with_const = sm.add_constant(x)
model = sm.OLS(y, x_with_const).fit()

x_pred = np.linspace(x.min(), x.max(), 100)
x_pred_with_const = sm.add_constant(x_pred)

predictions = model.get_prediction(x_pred_with_const)
pred_summary = predictions.summary_frame(alpha=0.05)  # 95% CI

mean_pred = pred_summary['mean'].values
mean_ci_lower = pred_summary['mean_ci_lower'].values
mean_ci_upper = pred_summary['mean_ci_upper'].values

# plot
fig, ax = plt.subplots(figsize=(10, 8))

ax.scatter(x, y, color='#b3cde3', s=50)
ax.plot(x_pred, mean_pred, color='#377eb8', linewidth=2) 
ax.fill_between(x_pred, mean_ci_lower, mean_ci_upper, color='#377eb8', alpha=0.3)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(1)
ax.xaxis.set_major_locator(MaxNLocator(nbins=7))

# Lables
corr, p_value = stats.pearsonr(x, y)
ax.set_title(f"Pearson r = {corr:.2f}, p = {p_value:.3f}", fontsize=24)
ax.set_xlabel('G-L Scale', fontsize=24)
ax.set_ylabel('Reading Time', fontsize=24)

ax.tick_params(axis='both', which='major', labelsize=20)

plt.tight_layout()
plt.show()
